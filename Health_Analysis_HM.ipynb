# %%
#Hypothesis
#If people with Alzheimer deasis stay active, then their well-being improves.

#Null Hypothesis
#The well-being of physically active patients stays the same or gets worse.

#Alternative Hypothesis
#The well-being of physically active patients improves.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
import json
import scipy.stats as stats
from scipy.stats import linregress

# %%
kaggle_data_df = pd.read_csv("resources/kaggle_alz.csv")
kaggle_data_df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc Datasource           Class  \
# 0       2020     2020           HI       Hawaii      BRFSS  Overall Health
# 1       2017     2017           ID        Idaho      BRFSS   Mental Health
# 2       2017     2017           ID        Idaho      BRFSS  Overall Health
# 3       2018     2018           ID        Idaho      BRFSS  Overall Health
# 4       2020     2020           IN      Indiana      BRFSS   Mental Health
#
#                                              Topic  \
# 0                     Arthritis among older adults
# 1                 Lifetime diagnosis of depression
# 2                     Arthritis among older adults
# 3  Physically unhealthy days (mean number of days)
# 4                 Lifetime diagnosis of depression
#
#                                             Question Data_Value_Unit  \
# 0  Percentage of older adults ever told they have...               %
# 1  Percentage of older adults with a lifetime dia...               %
# 2  Percentage of older adults ever told they have...               %
# 3  Physically unhealthy days (mean number of days...          Number
# 4  Percentage of older adults with a lifetime dia...               %
#
#   DataValueTypeID  ... Stratification2                       Geolocation  \
# 0           PRCTG  ...             NaN  POINT (-157.8577494 21.30485044)
# 1           PRCTG  ...             NaN    POINT (-114.36373 43.68263001)
# 2           PRCTG  ...             NaN    POINT (-114.36373 43.68263001)
# 3            MEAN  ...             NaN    POINT (-114.36373 43.68263001)
# 4           PRCTG  ...            Male  POINT (-86.14996019 39.76691045)
#
#    ClassID TopicID QuestionID  LocationID StratificationCategoryID1  \
# 0      C01   TOC11        Q43          15                       AGE
# 1      C05   TMC03        Q27          16                       AGE
# 2      C01   TOC11        Q43          16                       AGE
# 3      C01   TOC01        Q08          16                       AGE
# 4      C05   TMC03        Q27          18                       AGE
#
#   StratificationID1 StratificationCategoryID2 StratificationID2
# 0              5064                   OVERALL           OVERALL
# 1              5064                   OVERALL           OVERALL
# 2              5064                   OVERALL           OVERALL
# 3              5064                   OVERALL           OVERALL
# 4       AGE_OVERALL                    GENDER              MALE
#
# [5 rows x 29 columns]

# %%
kaggle_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214462 entries, 0 to 214461
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   YearStart                  214462 non-null  int64
#  1   YearEnd                    214462 non-null  int64
#  2   LocationAbbr               214462 non-null  object
#  3   LocationDesc               214462 non-null  object
#  4   Datasource                 214462 non-null  object
#  5   Class                      214462 non-null  object
#  6   Topic                      214462 non-null  object
#  7   Question                   214462 non-null  object
#  8   Data_Value_Unit            214462 non-null  object
#  9   DataValueTypeID            214462 non-null  object
#  10  Data_Value_Type            214462 non-null  object
#  11  Data_Value                 144629 non-null  float64
#  12  Data_Value_Alt             144629 non-null  float64
#  13  Low_Confidence_Limit       144472 non-null  object
#  14  High_Confidence_Limit      144472 non-null  object
#  15  Sample_Size                0 non-null       float64
#  16  StratificationCategory1    214462 non-null  object
#  17  Stratification1            214462 non-null  object
#  18  StratificationCategory2    186793 non-null  object
#  19  Stratification2            186793 non-null  object
#  20  Geolocation                191413 non-null  object
#  21  ClassID                    214462 non-null  object
#  22  TopicID                    214462 non-null  object
#  23  QuestionID                 214462 non-null  object
#  24  LocationID                 214462 non-null  int64
#  25  StratificationCategoryID1  214462 non-null  object
#  26  StratificationID1          214462 non-null  object
#  27  StratificationCategoryID2  214462 non-null  object
#  28  StratificationID2          214462 non-null  object
# dtypes: float64(3), int64(3), object(23)
# memory usage: 47.5+ MB

# %%
filtered_db = kaggle_data_df.loc[((kaggle_data_df['QuestionID'] =="Q32") | (kaggle_data_df['QuestionID'] =="Q35")) & ((kaggle_data_df['StratificationCategoryID1'] =="AGE") & (kaggle_data_df['StratificationID1'] =="AGE_OVERALL")) & ((kaggle_data_df['StratificationCategoryID2'] =="OVERALL") & (kaggle_data_df['StratificationID2'] =="OVERALL"))]
filtered_db.head()
# Out:
#      YearStart  YearEnd LocationAbbr LocationDesc Datasource           Class  \
# 90        2016     2016           AK       Alaska      BRFSS  Overall Health
# 542       2016     2016           AK       Alaska      BRFSS  Overall Health
# 613       2017     2017           AL      Alabama      BRFSS  Overall Health
# 741       2019     2019           AL      Alabama      BRFSS  Overall Health
# 913       2019     2019           AZ      Arizona      BRFSS  Overall Health
#
#                                          Topic  \
# 90   Recent activity limitations in past month
# 542    Self-rated health (fair to poor health)
# 613  Recent activity limitations in past month
# 741    Self-rated health (fair to poor health)
# 913    Self-rated health (fair to poor health)
#
#                                               Question Data_Value_Unit  \
# 90   Mean number of days with activity limitations ...          Number
# 542  Percentage of older adults who self-reported t...               %
# 613  Mean number of days with activity limitations ...          Number
# 741  Percentage of older adults who self-reported t...               %
# 913  Percentage of older adults who self-reported t...               %
#
#     DataValueTypeID  ... Stratification2                       Geolocation  \
# 90             MEAN  ...             NaN   POINT (-147.722059 64.84507996)
# 542           PRCTG  ...             NaN   POINT (-147.722059 64.84507996)
# 613            MEAN  ...             NaN  POINT (-86.63186076 32.84057112)
# 741           PRCTG  ...             NaN  POINT (-86.63186076 32.84057112)
# 913           PRCTG  ...             NaN  POINT (-111.7638113 34.86597028)
#
#      ClassID TopicID QuestionID  LocationID StratificationCategoryID1  \
# 90       C01   TOC03        Q35           2                       AGE
# 542      C01   TOC07        Q32           2                       AGE
# 613      C01   TOC03        Q35           1                       AGE
# 741      C01   TOC07        Q32           1                       AGE
# 913      C01   TOC07        Q32           4                       AGE
#
#     StratificationID1 StratificationCategoryID2 StratificationID2
# 90        AGE_OVERALL                   OVERALL           OVERALL
# 542       AGE_OVERALL                   OVERALL           OVERALL
# 613       AGE_OVERALL                   OVERALL           OVERALL
# 741       AGE_OVERALL                   OVERALL           OVERALL
# 913       AGE_OVERALL                   OVERALL           OVERALL
#
# [5 rows x 29 columns]

# %%
reduced_columns_less_active_df = filtered_db[['YearStart', 'LocationDesc', 'Geolocation', 'Data_Value_Unit', 'Data_Value', 'QuestionID', 'StratificationCategoryID1', 'StratificationID1', 'StratificationCategoryID2', 'StratificationID2']]
reduced_columns_less_active_df.reset_index(drop=True, inplace=True)
reduced_columns_less_active_df
# Out:
#      YearStart LocationDesc                       Geolocation Data_Value_Unit  \
# 0         2016       Alaska   POINT (-147.722059 64.84507996)          Number
# 1         2016       Alaska   POINT (-147.722059 64.84507996)               %
# 2         2017      Alabama  POINT (-86.63186076 32.84057112)          Number
# 3         2019      Alabama  POINT (-86.63186076 32.84057112)               %
# 4         2019      Arizona  POINT (-111.7638113 34.86597028)               %
# ..         ...          ...                               ...             ...
# 691       2018      Wyoming  POINT (-108.1098304 43.23554134)          Number
# 692       2016      Wyoming  POINT (-108.1098304 43.23554134)          Number
# 693       2015      Wyoming  POINT (-108.1098304 43.23554134)          Number
# 694       2016      Wyoming  POINT (-108.1098304 43.23554134)               %
# 695       2018      Wyoming  POINT (-108.1098304 43.23554134)               %
#
#      Data_Value QuestionID StratificationCategoryID1 StratificationID1  \
# 0           5.2        Q35                       AGE       AGE_OVERALL
# 1          19.2        Q32                       AGE       AGE_OVERALL
# 2           8.3        Q35                       AGE       AGE_OVERALL
# 3          31.1        Q32                       AGE       AGE_OVERALL
# 4          23.8        Q32                       AGE       AGE_OVERALL
# ..          ...        ...                       ...               ...
# 691         6.0        Q35                       AGE       AGE_OVERALL
# 692         6.1        Q35                       AGE       AGE_OVERALL
# 693         6.7        Q35                       AGE       AGE_OVERALL
# 694        20.6        Q32                       AGE       AGE_OVERALL
# 695        20.6        Q32                       AGE       AGE_OVERALL
#
#     StratificationCategoryID2 StratificationID2
# 0                     OVERALL           OVERALL
# 1                     OVERALL           OVERALL
# 2                     OVERALL           OVERALL
# 3                     OVERALL           OVERALL
# 4                     OVERALL           OVERALL
# ..                        ...               ...
# 691                   OVERALL           OVERALL
# 692                   OVERALL           OVERALL
# 693                   OVERALL           OVERALL
# 694                   OVERALL           OVERALL
# 695                   OVERALL           OVERALL
#
# [696 rows x 10 columns]

# %%
reduced_columns_less_active_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 696 entries, 0 to 695
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  696 non-null    int64
#  1   LocationDesc               696 non-null    object
#  2   Geolocation                636 non-null    object
#  3   Data_Value_Unit            696 non-null    object
#  4   Data_Value                 696 non-null    float64
#  5   QuestionID                 696 non-null    object
#  6   StratificationCategoryID1  696 non-null    object
#  7   StratificationID1          696 non-null    object
#  8   StratificationCategoryID2  696 non-null    object
#  9   StratificationID2          696 non-null    object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 54.5+ KB

# %%
less_active_poor_health_df = reduced_columns_less_active_df.pivot_table(index=['YearStart', 'LocationDesc', 'Geolocation',  'StratificationCategoryID1', 'StratificationID1', 'StratificationCategoryID2', 'StratificationID2'], columns='QuestionID', values = 'Data_Value').reset_index()
less_active_poor_health_df
# Out:
# QuestionID  YearStart   LocationDesc                       Geolocation  \
# 0                2015        Alabama  POINT (-86.63186076 32.84057112)
# 1                2015         Alaska   POINT (-147.722059 64.84507996)
# 2                2015        Arizona  POINT (-111.7638113 34.86597028)
# 3                2015       Arkansas  POINT (-92.27449074 34.74865012)
# 4                2015     California  POINT (-120.9999995 37.63864012)
# ..                ...            ...                               ...
# 313              2020       Virginia  POINT (-78.45789046 37.54268067)
# 314              2020     Washington  POINT (-120.4700108 47.52227863)
# 315              2020  West Virginia   POINT (-80.71264013 38.6655102)
# 316              2020      Wisconsin  POINT (-89.81637074 44.39319117)
# 317              2020        Wyoming  POINT (-108.1098304 43.23554134)
#
# QuestionID StratificationCategoryID1 StratificationID1  \
# 0                                AGE       AGE_OVERALL
# 1                                AGE       AGE_OVERALL
# 2                                AGE       AGE_OVERALL
# 3                                AGE       AGE_OVERALL
# 4                                AGE       AGE_OVERALL
# ..                               ...               ...
# 313                              AGE       AGE_OVERALL
# 314                              AGE       AGE_OVERALL
# 315                              AGE       AGE_OVERALL
# 316                              AGE       AGE_OVERALL
# 317                              AGE       AGE_OVERALL
#
# QuestionID StratificationCategoryID2 StratificationID2   Q32  Q35
# 0                            OVERALL           OVERALL  30.0  7.7
# 1                            OVERALL           OVERALL  19.5  5.7
# 2                            OVERALL           OVERALL  23.8  6.4
# 3                            OVERALL           OVERALL  34.4  8.2
# 4                            OVERALL           OVERALL  24.3  6.2
# ..                               ...               ...   ...  ...
# 313                          OVERALL           OVERALL  18.7  5.9
# 314                          OVERALL           OVERALL  16.7  5.8
# 315                          OVERALL           OVERALL  29.9  7.8
# 316                          OVERALL           OVERALL  15.2  5.5
# 317                          OVERALL           OVERALL  17.0  5.9
#
# [318 rows x 9 columns]

# %%
def linear_regression_plot(x_axis, y_axis):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    print(f"The r-value is: {rvalue}")
    reg_line = slope*x_axis + intercept
    fig = plt.figure(figsize =(9,6))
    ax = fig.add_subplot()
    plt.scatter(x_axis, y_axis, marker="o", s=70, edgecolors="black")
    plt.plot(x_axis,reg_line, color="r")
    
    #displaying regression equation on the chart
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))    
    ax.text(0.05, 0.1, line_eq, transform=ax.transAxes, fontsize=20, va='top', color='red')
 
    plt.rcParams['axes.labelsize'] = 14
    plt.xlabel("Inactive Days")
    plt.ylabel("People with Poor Health Condition (%)")
    plt.show()
    
    
    
linear_regression_plot(less_active_poor_health_df["Q35"], less_active_poor_health_df["Q32"])
# Out:
# The r-value is: 0.7520299363574254

# %%
population_state_df = pd.read_csv("resources/population.csv")
population_state_df
# Out:
#             States  Population
# 0          Alabama     4903185
# 1           Alaska      731545
# 2          Arizona     7278717
# 3         Arkansas     3017804
# 4       California    39512223
# 5         Colorado     5758736
# 6      Connecticut     3565287
# 7         Delaware      973764
# 8          Florida    21477737
# 9          Georgia    10617423
# 10          Hawaii     1415872
# 11           Idaho     1787065
# 12        Illinois    12671821
# 13         Indiana     6732219
# 14            Iowa     3155070
# 15          Kansas     2913314
# 16        Kentucky     4467673
# 17       Louisiana     4648794
# 18           Maine     1344212
# 19        Maryland     6045680
# 20   Massachusetts     6892503
# 21        Michigan     9986857
# 22       Minnesota     5639632
# 23     Mississippi     2976149
# 24        Missouri     6137428
# 25         Montana     1068778
# 26        Nebraska     1934408
# 27          Nevada     3080156
# 28   New Hampshire     1359711
# 29      New Jersey     8882190
# 30      New Mexico     2096829
# 31        New York    19453561
# 32  North Carolina    10488084
# 33    North Dakota      762062
# 34            Ohio    11689100
# 35        Oklahoma     3956971
# 36          Oregon     4217737
# 37    Pennsylvania    12801989
# 38    Rhode Island     1059361
# 39  South Carolina     5148714
# 40    South Dakota      884659
# 41       Tennessee     6829174
# 42           Texas    28995881
# 43            Utah     3205958
# 44         Vermont      623989
# 45        Virginia     8535519
# 46      Washington     7614893
# 47   West Virginia     1792147
# 48       Wisconsin     5822434
# 49         Wyoming      578759

# %%
mortality_state_df = pd.read_csv("resources/mortal_by_states_2019.csv")
mortality_state_df.set_index("States")
mortality_state_df
# Out:
#    States  Mortality
# 0      AL       2659
# 1      AK        128
# 2      AZ       3047
# 3      AR       1507
# 4      CA      16859
# 5      CO       1909
# 6      CT        967
# 7      DE        339
# 8      FL       6539
# 9      GA       4221
# 10     HI        471
# 11     ID        650
# 12     IL       3954
# 13     IN       2561
# 14     IA       1344
# 15     KS        839
# 16     KY       1684
# 17     LA       2165
# 18     ME        544
# 19     MD       1012
# 20     MA       1663
# 21     MI       4467
# 22     MN       2552
# 23     MS       1662
# 24     MO       2782
# 25     MT        326
# 26     NE        768
# 27     NV        678
# 28     NH        511
# 29     NJ       2629
# 30     NM        568
# 31     NY       3753
# 32     NC       4508
# 33     ND        403
# 34     OH       5234
# 35     OK       1775
# 36     OR       1992
# 37     PA       4150
# 38     RI        456
# 39     SC       2323
# 40     SD        495
# 41     TN       3252
# 42     TX      10101
# 43     UT        980
# 44     VT        315
# 45     VA       2631
# 46     WA       3585
# 47     WV        832
# 48     WI       2390
# 49     WY        238

# %%
merged_df = [[]]

# %%
merged_df = pd.merge(population_state_df, mortality_state_df, left_index=True, right_index=True)
merged_df.drop(columns=['States_y'])
merged_df
# Out:
#           States_x  Population States_y  Mortality
# 0          Alabama     4903185       AL       2659
# 1           Alaska      731545       AK        128
# 2          Arizona     7278717       AZ       3047
# 3         Arkansas     3017804       AR       1507
# 4       California    39512223       CA      16859
# 5         Colorado     5758736       CO       1909
# 6      Connecticut     3565287       CT        967
# 7         Delaware      973764       DE        339
# 8          Florida    21477737       FL       6539
# 9          Georgia    10617423       GA       4221
# 10          Hawaii     1415872       HI        471
# 11           Idaho     1787065       ID        650
# 12        Illinois    12671821       IL       3954
# 13         Indiana     6732219       IN       2561
# 14            Iowa     3155070       IA       1344
# 15          Kansas     2913314       KS        839
# 16        Kentucky     4467673       KY       1684
# 17       Louisiana     4648794       LA       2165
# 18           Maine     1344212       ME        544
# 19        Maryland     6045680       MD       1012
# 20   Massachusetts     6892503       MA       1663
# 21        Michigan     9986857       MI       4467
# 22       Minnesota     5639632       MN       2552
# 23     Mississippi     2976149       MS       1662
# 24        Missouri     6137428       MO       2782
# 25         Montana     1068778       MT        326
# 26        Nebraska     1934408       NE        768
# 27          Nevada     3080156       NV        678
# 28   New Hampshire     1359711       NH        511
# 29      New Jersey     8882190       NJ       2629
# 30      New Mexico     2096829       NM        568
# 31        New York    19453561       NY       3753
# 32  North Carolina    10488084       NC       4508
# 33    North Dakota      762062       ND        403
# 34            Ohio    11689100       OH       5234
# 35        Oklahoma     3956971       OK       1775
# 36          Oregon     4217737       OR       1992
# 37    Pennsylvania    12801989       PA       4150
# 38    Rhode Island     1059361       RI        456
# 39  South Carolina     5148714       SC       2323
# 40    South Dakota      884659       SD        495
# 41       Tennessee     6829174       TN       3252
# 42           Texas    28995881       TX      10101
# 43            Utah     3205958       UT        980
# 44         Vermont      623989       VT        315
# 45        Virginia     8535519       VA       2631
# 46      Washington     7614893       WA       3585
# 47   West Virginia     1792147       WV        832
# 48       Wisconsin     5822434       WI       2390
# 49         Wyoming      578759       WY        238

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   States_x    50 non-null     object
#  1   Population  50 non-null     int64
#  2   States_y    50 non-null     object
#  3   Mortality   50 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.7+ KB

# %%
merged_df['Population'] = merged_df['Population'].astype('int64')

# %%
mortality_percent = (merged_df['Mortality']/(merged_df['Population']))*100
mortality_percent
# Out:
# 0     0.054230
# 1     0.017497
# 2     0.041862
# 3     0.049937
# 4     0.042668
# 5     0.033150
# 6     0.027123
# 7     0.034813
# 8     0.030445
# 9     0.039755
# 10    0.033266
# 11    0.036372
# 12    0.031203
# 13    0.038041
# 14    0.042598
# 15    0.028799
# 16    0.037693
# 17    0.046571
# 18    0.040470
# 19    0.016739
# 20    0.024128
# 21    0.044729
# 22    0.045251
# 23    0.055844
# 24    0.045328
# 25    0.030502
# 26    0.039702
# 27    0.022012
# 28    0.037582
# 29    0.029599
# 30    0.027089
# 31    0.019292
# 32    0.042982
# 33    0.052883
# 34    0.044777
# 35    0.044858
# 36    0.047229
# 37    0.032417
# 38    0.043045
# 39    0.045118
# 40    0.055954
# 41    0.047619
# 42    0.034836
# 43    0.030568
# 44    0.050482
# 45    0.030824
# 46    0.047079
# 47    0.046425
# 48    0.041048
# 49    0.041122
# dtype: float64

# %%
plt.figure(figsize=(20,4))
plt.bar(merged_df['States_y'], merged_df['Mortality'], color='r', alpha=0.5, align="center")
# Out:
# <BarContainer object of 50 artists>

# %%
# Hypothesis by Gender

# %%
filtered_gender_db = kaggle_data_df.loc[((kaggle_data_df['QuestionID'] =="Q32") | (kaggle_data_df['QuestionID'] =="Q35")) & ((kaggle_data_df['StratificationCategoryID1'] =="AGE") & (kaggle_data_df['StratificationID1'] =="AGE_OVERALL")) & ((kaggle_data_df['StratificationCategoryID2'] =="GENDER") & ((kaggle_data_df['StratificationID2'] =="FEMALE") | (kaggle_data_df['StratificationID2'] =="MALE")))]
filtered_gender_db
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 15           2017     2017           KY     Kentucky      BRFSS
# 387          2018     2018           AL      Alabama      BRFSS
# 665          2020     2020           AZ      Arizona      BRFSS
# 1157         2017     2017           AL      Alabama      BRFSS
# 1681         2016     2016           AL      Alabama      BRFSS
# ...           ...      ...          ...          ...        ...
# 213763       2019     2019           WY      Wyoming      BRFSS
# 213865       2018     2018           WY      Wyoming      BRFSS
# 213986       2016     2016           WY      Wyoming      BRFSS
# 214013       2017     2017           WY      Wyoming      BRFSS
# 214159       2016     2016           WY      Wyoming      BRFSS
#
#                  Class                                      Topic  \
# 15      Overall Health  Recent activity limitations in past month
# 387     Overall Health  Recent activity limitations in past month
# 665     Overall Health  Recent activity limitations in past month
# 1157    Overall Health    Self-rated health (fair to poor health)
# 1681    Overall Health    Self-rated health (fair to poor health)
# ...                ...                                        ...
# 213763  Overall Health    Self-rated health (fair to poor health)
# 213865  Overall Health    Self-rated health (fair to poor health)
# 213986  Overall Health  Recent activity limitations in past month
# 214013  Overall Health    Self-rated health (fair to poor health)
# 214159  Overall Health  Recent activity limitations in past month
#
#                                                  Question Data_Value_Unit  \
# 15      Mean number of days with activity limitations ...          Number
# 387     Mean number of days with activity limitations ...          Number
# 665     Mean number of days with activity limitations ...          Number
# 1157    Percentage of older adults who self-reported t...               %
# 1681    Percentage of older adults who self-reported t...               %
# ...                                                   ...             ...
# 213763  Percentage of older adults who self-reported t...               %
# 213865  Percentage of older adults who self-reported t...               %
# 213986  Mean number of days with activity limitations ...          Number
# 214013  Percentage of older adults who self-reported t...               %
# 214159  Mean number of days with activity limitations ...          Number
#
#        DataValueTypeID  ... Stratification2                       Geolocation  \
# 15                MEAN  ...            Male  POINT (-84.77497105 37.64597027)
# 387               MEAN  ...          Female  POINT (-86.63186076 32.84057112)
# 665               MEAN  ...            Male  POINT (-111.7638113 34.86597028)
# 1157             PRCTG  ...            Male  POINT (-86.63186076 32.84057112)
# 1681             PRCTG  ...            Male  POINT (-86.63186076 32.84057112)
# ...                ...  ...             ...                               ...
# 213763           PRCTG  ...          Female  POINT (-108.1098304 43.23554134)
# 213865           PRCTG  ...          Female  POINT (-108.1098304 43.23554134)
# 213986            MEAN  ...            Male  POINT (-108.1098304 43.23554134)
# 214013           PRCTG  ...            Male  POINT (-108.1098304 43.23554134)
# 214159            MEAN  ...          Female  POINT (-108.1098304 43.23554134)
#
#         ClassID TopicID QuestionID  LocationID StratificationCategoryID1  \
# 15          C01   TOC03        Q35          21                       AGE
# 387         C01   TOC03        Q35           1                       AGE
# 665         C01   TOC03        Q35           4                       AGE
# 1157        C01   TOC07        Q32           1                       AGE
# 1681        C01   TOC07        Q32           1                       AGE
# ...         ...     ...        ...         ...                       ...
# 213763      C01   TOC07        Q32          56                       AGE
# 213865      C01   TOC07        Q32          56                       AGE
# 213986      C01   TOC03        Q35          56                       AGE
# 214013      C01   TOC07        Q32          56                       AGE
# 214159      C01   TOC03        Q35          56                       AGE
#
#        StratificationID1 StratificationCategoryID2 StratificationID2
# 15           AGE_OVERALL                    GENDER              MALE
# 387          AGE_OVERALL                    GENDER            FEMALE
# 665          AGE_OVERALL                    GENDER              MALE
# 1157         AGE_OVERALL                    GENDER              MALE
# 1681         AGE_OVERALL                    GENDER              MALE
# ...                  ...                       ...               ...
# 213763       AGE_OVERALL                    GENDER            FEMALE
# 213865       AGE_OVERALL                    GENDER            FEMALE
# 213986       AGE_OVERALL                    GENDER              MALE
# 214013       AGE_OVERALL                    GENDER              MALE
# 214159       AGE_OVERALL                    GENDER            FEMALE
#
# [1392 rows x 29 columns]

# %%
reduced_columns_gender_df = filtered_gender_db[['YearStart', 'LocationDesc', 'Geolocation', 'Data_Value_Unit', 'Data_Value', 'QuestionID', 'StratificationCategoryID1', 'StratificationID1', 'StratificationCategoryID2', 'StratificationID2']]
reduced_columns_gender_df.reset_index(drop=True, inplace=True)
reduced_columns_gender_df
# Out:
#       YearStart LocationDesc                       Geolocation  \
# 0          2017     Kentucky  POINT (-84.77497105 37.64597027)
# 1          2018      Alabama  POINT (-86.63186076 32.84057112)
# 2          2020      Arizona  POINT (-111.7638113 34.86597028)
# 3          2017      Alabama  POINT (-86.63186076 32.84057112)
# 4          2016      Alabama  POINT (-86.63186076 32.84057112)
# ...         ...          ...                               ...
# 1387       2019      Wyoming  POINT (-108.1098304 43.23554134)
# 1388       2018      Wyoming  POINT (-108.1098304 43.23554134)
# 1389       2016      Wyoming  POINT (-108.1098304 43.23554134)
# 1390       2017      Wyoming  POINT (-108.1098304 43.23554134)
# 1391       2016      Wyoming  POINT (-108.1098304 43.23554134)
#
#      Data_Value_Unit  Data_Value QuestionID StratificationCategoryID1  \
# 0             Number         8.7        Q35                       AGE
# 1             Number         7.8        Q35                       AGE
# 2             Number         6.3        Q35                       AGE
# 3                  %        32.6        Q32                       AGE
# 4                  %        30.5        Q32                       AGE
# ...              ...         ...        ...                       ...
# 1387               %        19.8        Q32                       AGE
# 1388               %        18.9        Q32                       AGE
# 1389          Number         6.3        Q35                       AGE
# 1390               %        18.7        Q32                       AGE
# 1391          Number         5.9        Q35                       AGE
#
#      StratificationID1 StratificationCategoryID2 StratificationID2
# 0          AGE_OVERALL                    GENDER              MALE
# 1          AGE_OVERALL                    GENDER            FEMALE
# 2          AGE_OVERALL                    GENDER              MALE
# 3          AGE_OVERALL                    GENDER              MALE
# 4          AGE_OVERALL                    GENDER              MALE
# ...                ...                       ...               ...
# 1387       AGE_OVERALL                    GENDER            FEMALE
# 1388       AGE_OVERALL                    GENDER            FEMALE
# 1389       AGE_OVERALL                    GENDER              MALE
# 1390       AGE_OVERALL                    GENDER              MALE
# 1391       AGE_OVERALL                    GENDER            FEMALE
#
# [1392 rows x 10 columns]

# %%
reduced_columns_gender_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1392 entries, 0 to 1391
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   YearStart                  1392 non-null   int64
#  1   LocationDesc               1392 non-null   object
#  2   Geolocation                1272 non-null   object
#  3   Data_Value_Unit            1392 non-null   object
#  4   Data_Value                 1392 non-null   float64
#  5   QuestionID                 1392 non-null   object
#  6   StratificationCategoryID1  1392 non-null   object
#  7   StratificationID1          1392 non-null   object
#  8   StratificationCategoryID2  1392 non-null   object
#  9   StratificationID2          1392 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 108.9+ KB

# %%
gender_mask_df = reduced_columns_gender_df.pivot_table(index=['YearStart', 'LocationDesc', 'Geolocation',  'StratificationCategoryID1', 'StratificationID1', 'StratificationCategoryID2', 'StratificationID2'], columns='QuestionID', values = 'Data_Value').reset_index()
gender_df = gender_mask_df.drop('StratificationCategoryID2',  axis = 1)
gender_df = gender_df.drop('StratificationCategoryID1',  axis = 1)
gender_df = gender_df.drop('StratificationID1',  axis = 1)
gender_df = gender_df.rename(columns = {'StratificationID2':'Gender', 'Q32':'Poor Health', 'Q35':'Inactive Days'})
gender_df.head(50)
# Out:
# QuestionID  YearStart          LocationDesc                       Geolocation  \
# 0                2015               Alabama  POINT (-86.63186076 32.84057112)
# 1                2015               Alabama  POINT (-86.63186076 32.84057112)
# 2                2015                Alaska   POINT (-147.722059 64.84507996)
# 3                2015                Alaska   POINT (-147.722059 64.84507996)
# 4                2015               Arizona  POINT (-111.7638113 34.86597028)
# 5                2015               Arizona  POINT (-111.7638113 34.86597028)
# 6                2015              Arkansas  POINT (-92.27449074 34.74865012)
# 7                2015              Arkansas  POINT (-92.27449074 34.74865012)
# 8                2015            California  POINT (-120.9999995 37.63864012)
# 9                2015            California  POINT (-120.9999995 37.63864012)
# 10               2015              Colorado  POINT (-106.1336109 38.84384076)
# 11               2015              Colorado  POINT (-106.1336109 38.84384076)
# 12               2015           Connecticut  POINT (-72.64984095 41.56266102)
# 13               2015           Connecticut  POINT (-72.64984095 41.56266102)
# 14               2015              Delaware  POINT (-75.57774117 39.00883067)
# 15               2015              Delaware  POINT (-75.57774117 39.00883067)
# 16               2015  District of Columbia      POINT (-77.036871 38.907192)
# 17               2015  District of Columbia      POINT (-77.036871 38.907192)
# 18               2015               Florida  POINT (-81.92896054 28.93204038)
# 19               2015               Florida  POINT (-81.92896054 28.93204038)
# 20               2015               Georgia  POINT (-83.62758035 32.83968109)
# 21               2015               Georgia  POINT (-83.62758035 32.83968109)
# 22               2015                  Guam      POINT (144.793731 13.444304)
# 23               2015                  Guam      POINT (144.793731 13.444304)
# 24               2015                Hawaii  POINT (-157.8577494 21.30485044)
# 25               2015                Hawaii  POINT (-157.8577494 21.30485044)
# 26               2015                 Idaho    POINT (-114.36373 43.68263001)
# 27               2015                 Idaho    POINT (-114.36373 43.68263001)
# 28               2015              Illinois  POINT (-88.99771018 40.48501028)
# 29               2015              Illinois  POINT (-88.99771018 40.48501028)
# 30               2015               Indiana  POINT (-86.14996019 39.76691045)
# 31               2015               Indiana  POINT (-86.14996019 39.76691045)
# 32               2015                  Iowa  POINT (-93.81649056 42.46940091)
# 33               2015                  Iowa  POINT (-93.81649056 42.46940091)
# 34               2015                Kansas   POINT (-98.20078123 38.3477403)
# 35               2015                Kansas   POINT (-98.20078123 38.3477403)
# 36               2015              Kentucky  POINT (-84.77497105 37.64597027)
# 37               2015              Kentucky  POINT (-84.77497105 37.64597027)
# 38               2015             Louisiana  POINT (-92.44568007 31.31266064)
# 39               2015             Louisiana  POINT (-92.44568007 31.31266064)
# 40               2015                 Maine  POINT (-68.98503134 45.25422889)
# 41               2015                 Maine  POINT (-68.98503134 45.25422889)
# 42               2015              Maryland  POINT (-76.60926011 39.29058096)
# 43               2015              Maryland  POINT (-76.60926011 39.29058096)
# 44               2015         Massachusetts  POINT (-72.08269067 42.27687047)
# 45               2015         Massachusetts  POINT (-72.08269067 42.27687047)
# 46               2015              Michigan  POINT (-84.71439027 44.66131954)
# 47               2015              Michigan  POINT (-84.71439027 44.66131954)
# 48               2015             Minnesota   POINT (-94.7942005 46.35564874)
# 49               2015             Minnesota   POINT (-94.7942005 46.35564874)
#
# QuestionID  Gender  Poor Health  Inactive Days
# 0           FEMALE         32.4            7.7
# 1             MALE         27.1            7.6
# 2           FEMALE         18.1            5.8
# 3             MALE         20.8            5.6
# 4           FEMALE         24.6            6.5
# 5             MALE         22.9            6.1
# 6           FEMALE         33.9            7.5
# 7             MALE         34.9            9.1
# 8           FEMALE         25.5            5.8
# 9             MALE         22.9            6.9
# 10          FEMALE         17.7            5.2
# 11            MALE         18.5            5.8
# 12          FEMALE         19.8            5.4
# 13            MALE         19.8            5.8
# 14          FEMALE         23.5            6.2
# 15            MALE         20.5            5.9
# 16          FEMALE         24.7            6.6
# 17            MALE         17.6            5.3
# 18          FEMALE         25.0            7.0
# 19            MALE         22.8            7.0
# 20          FEMALE         25.6            7.3
# 21            MALE         27.1            7.8
# 22          FEMALE         31.4            5.9
# 23            MALE         24.2            7.0
# 24          FEMALE         16.9            4.9
# 25            MALE         18.2            6.3
# 26          FEMALE         19.5            5.6
# 27            MALE         19.7            5.4
# 28          FEMALE         25.0            5.3
# 29            MALE         21.3            5.5
# 30          FEMALE         22.6            5.6
# 31            MALE         27.7            6.9
# 32          FEMALE         18.0            5.7
# 33            MALE         19.4            5.2
# 34          FEMALE         20.9            5.5
# 35            MALE         22.7            6.1
# 36          FEMALE         33.6            7.6
# 37            MALE         29.8            7.6
# 38          FEMALE         30.7            7.9
# 39            MALE         32.5            7.5
# 40          FEMALE         18.0            5.2
# 41            MALE         21.6            6.3
# 42          FEMALE         19.6            5.5
# 43            MALE         19.8            6.3
# 44          FEMALE         19.5            5.9
# 45            MALE         17.8            5.9
# 46          FEMALE         21.5            6.0
# 47            MALE         24.2            7.3
# 48          FEMALE         16.6            5.5
# 49            MALE         16.4            5.5

# %%
gender_category1 = gender_df[gender_df['Gender'] == 'FEMALE']['Poor Health'] # well-being data for category 1
gender_category2 = gender_df[gender_df['Gender'] == 'MALE']['Poor Health'] # well-being data for category 2
print (gender_category1)
print (gender_category2)

# Perform independent samples t-test
t_stat, p_value = stats.ttest_ind(gender_category1, gender_category2)  

# Print results
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# 0      32.4
# 2      18.1
# 4      24.6
# 6      33.9
# 8      25.5
#        ...
# 626    19.4
# 628    16.7
# 630    28.2
# 632    14.6
# 634    17.4
# Name: Poor Health, Length: 318, dtype: float64
# 1      27.1
# 3      20.8
# 5      22.9
# 7      34.9
# 9      22.9
#        ...
# 627    17.8
# 629    16.7
# 631    31.7
# 633    15.9
# 635    16.7
# Name: Poor Health, Length: 318, dtype: float64
# t-statistic: 0.3888480772932494
# p-value: 0.6975190881819724

# %%
# Set x axis and tick locations
x_axis = np.arange(len(gender_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
plt.figure(figsize=(20,4))
plt.bar(x_axis, gender_df["Poor Health"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, gender_df["Gender"], rotation="vertical")
plt.show()

# %%
 # Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(gender_df["Poor Health"])+10)
plt.show()

# %%
 # Set a Title and labels
plt.title("Average Percentage by Gender")
plt.xlabel("Gender")
plt.ylabel("Average Percentage Affected by Poor Health")
plt.show()

# %%
 # Save our graph and show the graph
plt.tight_layout()
plt.show()

# %%
# Hypothesis by Age

# %%
filtered_age_db = kaggle_data_df.loc[((kaggle_data_df['QuestionID'] =="Q32") | (kaggle_data_df['QuestionID'] =="Q35")) & ((kaggle_data_df['StratificationCategoryID1'] =="AGE") & ((kaggle_data_df['Stratification1'] =="50-64 years") | (kaggle_data_df['Stratification1'] =="65 years or older"))) & ((kaggle_data_df['StratificationCategoryID2'] =="OVERALL") & (kaggle_data_df['StratificationID2'] =="OVERALL"))]
filtered_age_db
# Out:
#         YearStart  YearEnd LocationAbbr LocationDesc Datasource  \
# 16           2015     2015           KY     Kentucky      BRFSS
# 45           2019     2019           AZ      Arizona      BRFSS
# 389          2019     2019           AK       Alaska      BRFSS
# 409          2019     2019           AL      Alabama      BRFSS
# 610          2016     2016           AL      Alabama      BRFSS
# ...           ...      ...          ...          ...        ...
# 213644       2018     2018           WY      Wyoming      BRFSS
# 213758       2019     2019           WY      Wyoming      BRFSS
# 213770       2019     2019           WY      Wyoming      BRFSS
# 213847       2017     2017           WY      Wyoming      BRFSS
# 214250       2015     2015           WY      Wyoming      BRFSS
#
#                  Class                                      Topic  \
# 16      Overall Health  Recent activity limitations in past month
# 45      Overall Health  Recent activity limitations in past month
# 389     Overall Health  Recent activity limitations in past month
# 409     Overall Health  Recent activity limitations in past month
# 610     Overall Health  Recent activity limitations in past month
# ...                ...                                        ...
# 213644  Overall Health  Recent activity limitations in past month
# 213758  Overall Health  Recent activity limitations in past month
# 213770  Overall Health    Self-rated health (fair to poor health)
# 213847  Overall Health  Recent activity limitations in past month
# 214250  Overall Health  Recent activity limitations in past month
#
#                                                  Question Data_Value_Unit  \
# 16      Mean number of days with activity limitations ...          Number
# 45      Mean number of days with activity limitations ...          Number
# 389     Mean number of days with activity limitations ...          Number
# 409     Mean number of days with activity limitations ...          Number
# 610     Mean number of days with activity limitations ...          Number
# ...                                                   ...             ...
# 213644  Mean number of days with activity limitations ...          Number
# 213758  Mean number of days with activity limitations ...          Number
# 213770  Percentage of older adults who self-reported t...               %
# 213847  Mean number of days with activity limitations ...          Number
# 214250  Mean number of days with activity limitations ...          Number
#
#        DataValueTypeID  ... Stratification2                       Geolocation  \
# 16                MEAN  ...             NaN  POINT (-84.77497105 37.64597027)
# 45                MEAN  ...             NaN  POINT (-111.7638113 34.86597028)
# 389               MEAN  ...             NaN   POINT (-147.722059 64.84507996)
# 409               MEAN  ...             NaN  POINT (-86.63186076 32.84057112)
# 610               MEAN  ...             NaN  POINT (-86.63186076 32.84057112)
# ...                ...  ...             ...                               ...
# 213644            MEAN  ...             NaN  POINT (-108.1098304 43.23554134)
# 213758            MEAN  ...             NaN  POINT (-108.1098304 43.23554134)
# 213770           PRCTG  ...             NaN  POINT (-108.1098304 43.23554134)
# 213847            MEAN  ...             NaN  POINT (-108.1098304 43.23554134)
# 214250            MEAN  ...             NaN  POINT (-108.1098304 43.23554134)
#
#         ClassID TopicID QuestionID  LocationID StratificationCategoryID1  \
# 16          C01   TOC03        Q35          21                       AGE
# 45          C01   TOC03        Q35           4                       AGE
# 389         C01   TOC03        Q35           2                       AGE
# 409         C01   TOC03        Q35           1                       AGE
# 610         C01   TOC03        Q35           1                       AGE
# ...         ...     ...        ...         ...                       ...
# 213644      C01   TOC03        Q35          56                       AGE
# 213758      C01   TOC03        Q35          56                       AGE
# 213770      C01   TOC07        Q32          56                       AGE
# 213847      C01   TOC03        Q35          56                       AGE
# 214250      C01   TOC03        Q35          56                       AGE
#
#        StratificationID1 StratificationCategoryID2 StratificationID2
# 16                  5064                   OVERALL           OVERALL
# 45                65PLUS                   OVERALL           OVERALL
# 389               65PLUS                   OVERALL           OVERALL
# 409                 5064                   OVERALL           OVERALL
# 610                 5064                   OVERALL           OVERALL
# ...                  ...                       ...               ...
# 213644              5064                   OVERALL           OVERALL
# 213758            65PLUS                   OVERALL           OVERALL
# 213770              5064                   OVERALL           OVERALL
# 213847              5064                   OVERALL           OVERALL
# 214250            65PLUS                   OVERALL           OVERALL
#
# [1392 rows x 29 columns]

# %%
reduced_columns_age_df = filtered_age_db[['YearStart', 'LocationDesc', 'Geolocation', 'Data_Value_Unit', 'Data_Value', 'QuestionID', 'StratificationCategoryID1', 'StratificationID1', 'StratificationCategoryID2', 'StratificationID2']]
reduced_columns_age_df.reset_index(drop=True, inplace=True)
reduced_columns_age_df
# Out:
#       YearStart LocationDesc                       Geolocation  \
# 0          2015     Kentucky  POINT (-84.77497105 37.64597027)
# 1          2019      Arizona  POINT (-111.7638113 34.86597028)
# 2          2019       Alaska   POINT (-147.722059 64.84507996)
# 3          2019      Alabama  POINT (-86.63186076 32.84057112)
# 4          2016      Alabama  POINT (-86.63186076 32.84057112)
# ...         ...          ...                               ...
# 1387       2018      Wyoming  POINT (-108.1098304 43.23554134)
# 1388       2019      Wyoming  POINT (-108.1098304 43.23554134)
# 1389       2019      Wyoming  POINT (-108.1098304 43.23554134)
# 1390       2017      Wyoming  POINT (-108.1098304 43.23554134)
# 1391       2015      Wyoming  POINT (-108.1098304 43.23554134)
#
#      Data_Value_Unit  Data_Value QuestionID StratificationCategoryID1  \
# 0             Number         8.1        Q35                       AGE
# 1             Number         5.5        Q35                       AGE
# 2             Number         5.7        Q35                       AGE
# 3             Number         8.5        Q35                       AGE
# 4             Number         7.9        Q35                       AGE
# ...              ...         ...        ...                       ...
# 1387          Number         6.0        Q35                       AGE
# 1388          Number         6.6        Q35                       AGE
# 1389               %        22.2        Q32                       AGE
# 1390          Number         5.7        Q35                       AGE
# 1391          Number         6.4        Q35                       AGE
#
#      StratificationID1 StratificationCategoryID2 StratificationID2
# 0                 5064                   OVERALL           OVERALL
# 1               65PLUS                   OVERALL           OVERALL
# 2               65PLUS                   OVERALL           OVERALL
# 3                 5064                   OVERALL           OVERALL
# 4                 5064                   OVERALL           OVERALL
# ...                ...                       ...               ...
# 1387              5064                   OVERALL           OVERALL
# 1388            65PLUS                   OVERALL           OVERALL
# 1389              5064                   OVERALL           OVERALL
# 1390              5064                   OVERALL           OVERALL
# 1391            65PLUS                   OVERALL           OVERALL
#
# [1392 rows x 10 columns]

# %%
age_mask_df = reduced_columns_age_df.pivot_table(index=['YearStart', 'LocationDesc', 'Geolocation',  'StratificationCategoryID1', 'StratificationID1', 'StratificationCategoryID2', 'StratificationID2'], columns='QuestionID', values = 'Data_Value').reset_index()

#gender_df = gender_mask_df[['YearStart', 'LocationDesc', 'Geolocation', 'Data_Value_Unit', 'Data_Value', 'QuestionID', 'StratificationCategoryID1', 'StratificationID1', 'StratificationID2']].copy()
age1_df = age_mask_df.drop('StratificationCategoryID1', axis = 1)
age2_df = age1_df.drop('StratificationCategoryID2', axis = 1)
age3_df = age2_df.drop('StratificationID2', axis = 1)
#age2_df = 'StratificationCategoryID2', 'StratificationID2',
age_df = age3_df.rename(columns = {'StratificationID1':'Age Group', 'Q32':'Poor Health', 'Q35':'Inactive Days'})
age_df.tail(50)
# Out:
# QuestionID  YearStart    LocationDesc                       Geolocation  \
# 586              2020        Nebraska  POINT (-99.36572062 41.64104099)
# 587              2020        Nebraska  POINT (-99.36572062 41.64104099)
# 588              2020          Nevada  POINT (-117.0718406 39.49324039)
# 589              2020          Nevada  POINT (-117.0718406 39.49324039)
# 590              2020   New Hampshire  POINT (-71.50036092 43.65595011)
# 591              2020   New Hampshire  POINT (-71.50036092 43.65595011)
# 592              2020      New Jersey  POINT (-74.27369129 40.13057005)
# 593              2020      New Jersey  POINT (-74.27369129 40.13057005)
# 594              2020      New Mexico   POINT (-106.240581 34.52088095)
# 595              2020      New Mexico   POINT (-106.240581 34.52088095)
# 596              2020        New York  POINT (-75.54397043 42.82700103)
# 597              2020        New York  POINT (-75.54397043 42.82700103)
# 598              2020  North Carolina  POINT (-79.15925046 35.46622098)
# 599              2020  North Carolina  POINT (-79.15925046 35.46622098)
# 600              2020    North Dakota   POINT (-100.118421 47.47531978)
# 601              2020    North Dakota   POINT (-100.118421 47.47531978)
# 602              2020            Ohio  POINT (-82.40426006 40.06021014)
# 603              2020            Ohio  POINT (-82.40426006 40.06021014)
# 604              2020        Oklahoma  POINT (-97.52107021 35.47203136)
# 605              2020        Oklahoma  POINT (-97.52107021 35.47203136)
# 606              2020          Oregon  POINT (-120.1550313 44.56744942)
# 607              2020          Oregon  POINT (-120.1550313 44.56744942)
# 608              2020    Pennsylvania  POINT (-77.86070029 40.79373015)
# 609              2020    Pennsylvania  POINT (-77.86070029 40.79373015)
# 610              2020     Puerto Rico      POINT (-66.590149 18.220833)
# 611              2020     Puerto Rico      POINT (-66.590149 18.220833)
# 612              2020    Rhode Island  POINT (-71.52247031 41.70828019)
# 613              2020    Rhode Island  POINT (-71.52247031 41.70828019)
# 614              2020  South Carolina   POINT (-81.04537121 33.9988213)
# 615              2020  South Carolina   POINT (-81.04537121 33.9988213)
# 616              2020    South Dakota  POINT (-100.3735306 44.35313005)
# 617              2020    South Dakota  POINT (-100.3735306 44.35313005)
# 618              2020       Tennessee  POINT (-85.77449091 35.68094058)
# 619              2020       Tennessee  POINT (-85.77449091 35.68094058)
# 620              2020           Texas  POINT (-99.42677021 31.82724041)
# 621              2020           Texas  POINT (-99.42677021 31.82724041)
# 622              2020            Utah  POINT (-111.5871306 39.36070017)
# 623              2020            Utah  POINT (-111.5871306 39.36070017)
# 624              2020         Vermont  POINT (-72.51764079 43.62538124)
# 625              2020         Vermont  POINT (-72.51764079 43.62538124)
# 626              2020        Virginia  POINT (-78.45789046 37.54268067)
# 627              2020        Virginia  POINT (-78.45789046 37.54268067)
# 628              2020      Washington  POINT (-120.4700108 47.52227863)
# 629              2020      Washington  POINT (-120.4700108 47.52227863)
# 630              2020   West Virginia   POINT (-80.71264013 38.6655102)
# 631              2020   West Virginia   POINT (-80.71264013 38.6655102)
# 632              2020       Wisconsin  POINT (-89.81637074 44.39319117)
# 633              2020       Wisconsin  POINT (-89.81637074 44.39319117)
# 634              2020         Wyoming  POINT (-108.1098304 43.23554134)
# 635              2020         Wyoming  POINT (-108.1098304 43.23554134)
#
# QuestionID Age Group  Poor Health  Inactive Days
# 586             5064         13.8            5.3
# 587           65PLUS         18.5            5.0
# 588             5064         23.1            7.3
# 589           65PLUS         26.0            6.5
# 590             5064         12.5            5.4
# 591           65PLUS         15.3            4.6
# 592             5064         14.1            5.2
# 593           65PLUS         19.5            5.1
# 594             5064         17.7            6.6
# 595           65PLUS         24.4            6.1
# 596             5064         15.5            6.1
# 597           65PLUS         20.7            6.0
# 598             5064         18.1            6.2
# 599           65PLUS         24.1            7.6
# 600             5064         13.2            5.3
# 601           65PLUS         19.9            4.5
# 602             5064         19.0            6.2
# 603           65PLUS         23.1            6.1
# 604             5064         25.2            7.5
# 605           65PLUS         27.3            6.4
# 606             5064         16.8            6.6
# 607           65PLUS         20.2            6.6
# 608             5064         15.1            5.8
# 609           65PLUS         23.0            6.1
# 610             5064         36.8            6.7
# 611           65PLUS         50.3            7.1
# 612             5064         15.4            6.4
# 613           65PLUS         18.3            5.6
# 614             5064         24.9            8.0
# 615           65PLUS         23.7            6.9
# 616             5064         11.4            5.3
# 617           65PLUS         19.4            4.4
# 618             5064         21.8            7.4
# 619           65PLUS         27.2            6.0
# 620             5064         22.4            6.9
# 621           65PLUS         23.9            5.5
# 622             5064         15.1            6.0
# 623           65PLUS         17.4            5.3
# 624             5064         12.3            5.2
# 625           65PLUS         16.4            4.8
# 626             5064         16.7            6.0
# 627           65PLUS         21.0            5.7
# 628             5064         14.8            5.5
# 629           65PLUS         18.9            6.1
# 630             5064         28.7            8.6
# 631           65PLUS         31.0            7.0
# 632             5064         14.8            5.8
# 633           65PLUS         15.8            5.3
# 634             5064         16.3            6.0
# 635           65PLUS         17.8            5.9

# %%
age_category1 = age_df[age_df['Age Group'] == '5064']['Poor Health'] # well-being data for category 1
age_category2 = age_df[age_df['Age Group'] == '65PLUS']['Poor Health'] # well-being data for category 2
print (age_category1)
print (age_category2)

# Perform independent samples t-test
t_stat, p_value = stats.ttest_ind(age_category1, age_category2)  

# Print results
print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# 0      28.3
# 2      16.5
# 4      23.8
# 6      37.0
# 8      23.6
#        ...
# 626    16.7
# 628    14.8
# 630    28.7
# 632    14.8
# 634    16.3
# Name: Poor Health, Length: 318, dtype: float64
# 1      32.1
# 3      25.2
# 5      23.8
# 7      31.2
# 9      25.3
#        ...
# 627    21.0
# 629    18.9
# 631    31.0
# 633    15.8
# 635    17.8
# Name: Poor Health, Length: 318, dtype: float64
# t-statistic: -5.053223881334154
# p-value: 5.689849928373237e-07
